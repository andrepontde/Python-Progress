# %%
import requests

# %%
result = requests.get('https://annapurnainteractive.com/en')

# %%
type(result)
# Out:
# requests.models.Response

# %%
print(result.text)
# Out:
#
#
#
# <!doctype html>
# <html lang="en">
# <head>
#
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width,initial-scale=1.0">
#
#   <title>Games - Annapurna Interactive</title>
#   <!-- Search engines -->
# <meta name="description" content="Annapurna Interactive works with game creators from around the world, helping them create and release personal experiences for everyone.">
# <!-- Google Plus -->
# <!-- Update your html tag to include the itemscope and itemtype attributes. -->
# <!-- html itemscope itemtype="http://schema.org/{CONTENT_TYPE}" -->
# <meta itemprop="name" content="Annapurna Interactive">
# <meta itemprop="description" content="Annapurna Interactive works with game creators from around the world, helping them create and release personal experiences for everyone.">
# <!-- Twitter -->
# <meta name="twitter:card" content="summary_large_image">
# <meta name="twitter:site" content="@a_i">
# ...

# %%
import bs4

# %%
import lxml

# %%
soup = bs4.BeautifulSoup(result.text, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1.0" name="viewport"/>
# <title>Games - Annapurna Interactive</title>
# <!-- Search engines -->
# <meta content="Annapurna Interactive works with game creators from around the world, helping them create and release personal experiences for everyone." name="description"/>
# <!-- Google Plus -->
# <!-- Update your html tag to include the itemscope and itemtype attributes. -->
# <!-- html itemscope itemtype="http://schema.org/{CONTENT_TYPE}" -->
# <meta content="Annapurna Interactive" itemprop="name"/>
# <meta content="Annapurna Interactive works with game creators from around the world, helping them create and release personal experiences for everyone." itemprop="description"/>
# <!-- Twitter -->
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@a_i" name="twitter:site"/>
# <meta content="Annapurna Interactive" name="twitter:title"/>
# ...

# %%
soup.select('title')
# Out:
# [<title>Games - Annapurna Interactive</title>]

# %%
soup.select('h1')
# Out:
# [<h1 class="header__logo">
#  <a class="header__logo-link" href="https://annapurnainteractive.com/en">
#  <span class="show-for-sr">Annapurna Interactive</span>
#  </a>
#  </h1>,
#  <h1 class="featured__heading heading-color">
#                  Lorelei and the Laser Eyes    </h1>,
#  <h1 class="featured__heading heading-color">
#                  Open Roads    </h1>,
#  <h1 class="featured__heading heading-color">
#                  Outer Wilds    </h1>]

# %%
soup.select('title')[0].getText()
# Out:
# 'Games - Annapurna Interactive'

# %%
site_paragraphs = ''

for text in soup.select('p'):
    site_paragraphs = site_paragraphs + text.getText()    
    
#I am a fucking genius I aint gonna lie

# %%
site_paragraphs
# Out:
# 'Blade Runner 2033: LabyrinthWe Kill MonstersGhost Biketo a TLushfoil Photography SimFlockBounty StarThe Lost WildForever AgoSkin DeepLorelei and the Laser EyesOpen RoadsThirsty SuitorsCOCOONMundaunStorytellerHindsightHohokumStrayNeon WhiteA Memoir BlueSolar AshThe Artful EscapeTwelve MinutesLast StopMaquetteThe PathlessI Am DeadThe Unfinished SwanIf Found…Kentucky Route Zero: TV EditionWattamSayonara Wild HeartsTelling LiesJourneyOuter WildsAshenFlorenceDonut CountyGone HomeGorogoaFlowerWhat Remains of Edith FinchSubscribe to the newsletter\r\n\r\n        \n\n\nThis site uses cookies to enhance your experience. More info'

# %%
#Now we are grabbing all the elements on a class in a website
